# %% [markdown]
# Due to the current situation (`Updated 09/02/2026`),
#
# - Google Gemini has reduced the rate limits for several models, such as `gemini-2.5-flash` and `gemini-3-flash` (text models used in Colab notebooks), to a **limit of 20 Requests Per Day (RPD)**.
#
# - To continue using these models seamlessly with sufficient rate limits, it is necessary to upgrade to the **pay-as-you-go tier** (link a Billing Account).
#   - 👉 You can learn how to do this here: [https://ai.google.dev/gemini-api/docs/billing](https://ai.google.dev/gemini-api/docs/billing)
#
# - Alternatively, you can follow the Groq API approach described below.
#
# - Updated `23/08/2026`: Changed from Llama to Qwen because the previously used Groq models are no longer supported.

# %% [markdown]
# # RAG Demo
# Note: Code mostly copied from LangChain's tutorial https://python.langchain.com/docs/tutorials/rag/
#
# This tutorial will show you how to implement a simple RAG pipeline.

# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install -qU langchain
# !pip install -qU langchain-huggingface
# !pip install -qU langchain-chroma
# !pip install -qU langchain-community
# !pip install -qU langgraph
# !pip install -qU pypdf
# !pip install -q fixthaipdf
# !pip install sentence-transformers

# %% [markdown]
# (Optional) — Run the code below to enable text wrapping in the output block for better readability.

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# # Code

# %% [markdown]
# ## Components

# %% [markdown]
# LLM (a part of generation)
# - used for generating the final answer to the user's question, by taking the retrieved context and the question as input.

# %% [markdown]
# ### Approach 1: Gemini

# %%
# %%capture
# !pip install -qU langchain-google-genai
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Request for Google API KEY here : https://aistudio.google.com/app/apikey

# %%
# from getpass
# import os

# os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI

# llm = ChatGoogleGenerativeAI(
#     model="gemini-2.5-flash",
#     temperature=0.7,
#     max_tokens=None,
#     timeout=None,
#     max_retries=2,
#     # other params...
# )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Approach 2: Groq API

# %% [markdown]
# However, we still have an **alternative** that can be used via a free-tier API: **Groq API** (compatible with LangChain). This does not require linking a credit card and offers several models, such as:
#
# Available models: https://console.groq.com/settings/limits
#
# 👉 You can sign up and get your API Key here: [https://console.groq.com/keys](https://console.groq.com/keys)

# %%
# !pip install -qU langchain-groq
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.4 MB/s eta 0:00:00

# %%
import getpass
import os

os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Enter your Groq API key: ··········

# %% [markdown]
# The model temperature is configured in the LLM setup at the beginning of this notebook. For RAG, a lower temperature is often preferred when we want more consistent, grounded answers.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="qwen/qwen3.6-27b",
    reasoning_effort="none",
    max_tokens=600,
    timeout=None,
    max_retries=2,
)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Embedding Model (a part of retrieval)
# - The HuggingFaceEmbeddings(`model_name="BAAI/bge-m3"`) is used to convert the text documents (and user queries) into numerical vector representations (embeddings).
# - These embeddings capture the semantic meaning of the text, allowing for similarity comparisons.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-m3")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B / 2.27GB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 2.27GB
# model.safetensors: downloading bytes:           |  0.00B
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model: reconstructing file:   0%|          |  0.00B / 5.07MB
# sentencepiece.bpe.model: downloading bytes:           |  0.00B
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 17.1MB
# tokenizer.json: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %% [markdown]
# Vector Database (a part of retrieval)
# - `Chroma` serves as the vector database. Its purpose is to store the embeddings generated from the document chunks and enable efficient similarity searches.
# - When a user asks a question, `its embedding` is compared against the `stored document embeddings` to find the most relevant document chunks.

# %%
from langchain_chroma import Chroma

vector_store = Chroma(embedding_function=embeddings)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Retrieval

# %% [markdown]
# To build a retrieval part, it contains 3 steps :
# - (1) Load a Document --> (2) Splitting --> (3) Storing

# %% [markdown]
# ### Loading a Document
#
# We will be using CR99 from Reg Chula as our document. To load this pdf, we will use `PyPDFLoader`.
#
# You can download the document here (choose only one):
# - Thai Version: https://www.reg.chula.ac.th/CR99_2025_Th.pdf
# - Eng Version: https://web.reg.chula.ac.th/CR99_2023_EngS.pdf

# %%
# !wget https://web.reg.chula.ac.th/CR99_2023_EngS.pdf --no-check-certificate # eng ver.
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# --2026-09-11 06:06:27--  https://web.reg.chula.ac.th/CR99_2023_EngS.pdf
# Resolving web.reg.chula.ac.th (web.reg.chula.ac.th)... 161.200.133.230
# Connecting to web.reg.chula.ac.th (web.reg.chula.ac.th)|161.200.133.230|:443... connected.
# WARNING: cannot verify web.reg.chula.ac.th's certificate, issued by ‘CN=GlobalSign RSA OV SSL CA 2018,O=GlobalSign nv-sa,C=BE’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1670989 (1.6M) [application/pdf]
# Saving to: ‘CR99_2023_EngS.pdf’
#
# CR99_2023_EngS.pdf  100%[===================>]   1.59M  1.35MB/s    in 1.2s
#
# 2026-09-11 06:06:30 (1.35 MB/s) - ‘CR99_2023_EngS.pdf’ saved [1670989/1670989]

# %%
file_name = "CR99_2023_EngS" # @param {"type":"string"}
from langchain_community.document_loaders import PyPDFLoader
from fixthaipdf import clean

file_path = (
    f"/content/{file_name}.pdf"
)
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()

pages[0]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /tmp/ipykernel_1553/3253731762.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2023-09-22T15:10:46+07:00', 'author': 'Office of the Registrar', 'moddate': '2023-09-22T16:11:28+07:00', 'title': '', 'source': '/content/CR99_2023_EngS.pdf', 'total_pages': 35, 'page': 0, 'page_label': '1'}, page_content='CR99\nStudent Registration Manual\nAcademic Year 2023')

# %%
for page in pages:
  page.page_content = clean(page.page_content)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
print(pages[1])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# page_content='The Student Registration Manual is compiled by the Office of the Registrar to provide
# both undergraduate and graduate students understanding in processes involved in student
# registration, starting from their first enrollment into Chulalongkorn University up until to their
# graduation. It contains guideline on registration process, required documents, schedules,
# and contact information.
# Nevertheless, throughout the academic year, it is possible that there might be some
# change in details regardi ng registration processs. It is highly recommended that all students
# should follow latest information, procedures, or schedule at the Office of the Registrar’s
# website (https://www.reg.chula.ac.th) regularly to ensure that they do not miss the deadline
# or any steps in registration.
# We hope that this manual will be of use throughout your study in Chulalongkorn
# University.
# Contact Us
# Location Chamchuri 6 Building
# Time Office Hours: 8:00 AM – 5:00 PM (Mon. – Fri.)
# Payment Hours: 8:00 AM – 4:00 PM (Mon. – Fri.)
# Closed on weekends and public holidays.
# Please bring your student card/ID card/passport and wear proper attire when contact.
# It is in your best interest to read this CR99 along with
# Chu lalongkorn University Regulations on Undergraduate
# Studies B.E. 2556 ,2565 or Regulations on Graduate
# Studies B.E. 2561 thoroughly.' metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2023-09-22T15:10:46+07:00', 'author': 'Office of the Registrar', 'moddate': '2023-09-22T16:11:28+07:00', 'title': '', 'source': '/content/CR99_2023_EngS.pdf', 'total_pages': 35, 'page': 1, 'page_label': '2'}

# %% [markdown]
# ### Splitting documents
#
# Our loaded document is too long to fit
# into the context window of many models. Even for those models that could
# fit the full post in their context window, models can struggle to find
# information in very long inputs.
#
# To handle this we’ll split the `Document`s into chunks for embedding and
# vector storage. This should help us retrieve only the most relevant parts
# of the blog post at run time.
#
# We use a
# [RecursiveCharacterTextSplitter](https://python.langchain.com/docs/how_to/recursive_text_splitter/),
# which will recursively split the document using common separators like
# new lines until each chunk is the appropriate size. This is the
# recommended text splitter for generic text use cases.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # chunk size (characters)
    chunk_overlap=200,      # chunk overlap (characters)
    add_start_index=True,   # track index in original document
)
all_splits = text_splitter.split_documents(pages)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Split blog post into 87 sub-documents.

# %% [markdown]
# ### Storing documents
#
# Now we need to index our text chunks so that we can search over them
# at runtime. Our approach is to [embed](https://python.langchain.com/docs/concepts/embedding_models/) the contents of each document split and insert these embeddings
# into a [vector store](https://python.langchain.com/docs/concepts/vectorstores/). Given an input query, we can then use
# vector search to retrieve relevant documents.
#
# We can embed and store all of our document splits in a single command
# using the vector store and embeddings model selected at the [start of the tutorial](https://python.langchain.com/docs/tutorials/rag/#components).

# %%
document_ids = vector_store.add_documents(documents=all_splits)
print(document_ids[:3])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ['e3abf3cb-aa88-45f7-995f-c2dea9e50c8c', 'dded5e30-b60f-4be2-ae89-f829fe4a57c0', '6300e3ed-0ade-49f7-b919-3486abd072e3']

# %% [markdown]
# ### Test our Vector Database (Retrieval Part)

# %% [markdown]
# - When you provide a query (like 'Loss my student card') it performs a similarity search to find and return the most relevant document chunks based on their meaning, not just keyword matches.
# - This retrieval capability is the foundation for a complete RAG pipeline. The next step, as you mentioned, would be to integrate an LLM to generate a coherent answer based on these retrieved documents and the original query.

# %% [markdown]
# - Ex. query = "Loss a Student Card"

# %%
query = "What should I do if I lose my student card?"
retrieved_docs = vector_store.similarity_search(query)

print(f"Query: {query}\n")
print("Retrieved Documents:")
print("="*50)
for i, doc in enumerate(retrieved_docs):
    print(f"-- Document Relevance Rank no. {i+1} --")
    print(f"Content: {doc.page_content}...") # Print first 500 characters
    print(f"Metadata: {doc.metadata}\n")
    print("="*50)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Query: What should I do if I lose my student card?
#
# Retrieved Documents:
# ==================================================
# -- Document Relevance Rank no. 1 --
# Content: Student Card
# Chulalongkorn University in cooperation with Kasikorn Bank (KBank) will issue student cards for
# every new students in their first semester. Following are benefits and privileges of the student card:
# 1. Identifying oneself as a student of the University to gain access to libraries and other facilities
# of the University such as CU Health Service Center and CU Sports Complex.
# 2. Student card will also serve as a debit card of KBank. No application or annual fee is charged
# throughout the period of study at Chulalongkorn University.
# 3. Other privileges as announced by Kasikorn Bank.
# Request for Replacement of Student Card
# Request for replacement of student card due to defect, loss, expiration, or name change can
# be done by 3 methods.
#  Request at the Office of the Registrar
# 1. Submit CR50 form and pay 100 baht fee at the Office of the Registrar
# 2. Bring the following documents to 2 branches of Kasikorn Bank (Chamchuri Square or...
# Metadata: {'author': 'Office of the Registrar', 'start_index': 0, 'creator': 'Microsoft® Word 2013', 'source': '/content/CR99_2023_EngS.pdf', 'moddate': '2023-09-22T16:11:28+07:00', 'title': '', 'page_label': '10', 'producer': 'Microsoft® Word 2013', 'total_pages': 35, 'creationdate': '2023-09-22T15:10:46+07:00', 'page': 9}
#
# ==================================================
# -- Document Relevance Rank no. 2 --
# Content:  Request at the Office of the Registrar
# 1. Submit CR50 form and pay 100 baht fee at the Office of the Registrar
# 2. Bring the following documents to 2 branches of Kasikorn Bank (Chamchuri Square or
# Chulalongkorn Hospital) during business hours of the bank to retrieve the new student card.
# a) Receipt Form for a Student Card
# b) Identification Card or Passport
# c) Kasikorn Bank Personal Records Modification Document (in case of name change)
# d) Kasikorn Bank Account Book Bank
#  Request Online
# 1. Download CR50 form at www.reg.chula.ac.th
# 2. Complete both section of the form.
# 3. Deposit the amount of 100 baht to: SIAM COMMERCIAL BANK Account Name: Office of the
# Registrar, Chulalongkorn University Account Number: 401-270276-5
# 4. Send the CR50 form and proof of deposit to webreg@chula.ac.th
# 5. The staff will verify your information and send the document to retrieve the new card to your e -mail
# within 3 working days.
#  Request via CUNEX Application (only in cases of loss, defect, or extension)...
# Metadata: {'page_label': '10', 'start_index': 752, 'creator': 'Microsoft® Word 2013', 'title': '', 'producer': 'Microsoft® Word 2013', 'total_pages': 35, 'author': 'Office of the Registrar', 'page': 9, 'source': '/content/CR99_2023_EngS.pdf', 'moddate': '2023-09-22T16:11:28+07:00', 'creationdate': '2023-09-22T15:10:46+07:00'}
#
# ==================================================
# -- Document Relevance Rank no. 3 --
# Content: within 3 working days.
#  Request via CUNEX Application (only in cases of loss, defect, or extension)
# 1. Request for new student card through “Student Card” menu in CUNEX Application.
# 2. Download CR50 form at www.reg.chula.ac.th and complete both section of the form.
# 3. Deposit the amount of 100 baht to: SIAM COMMERCIAL BANK Account Name: Offi ce of the
# Registrar, Chulalongkorn University Account Number: 401-270276-5
# 4. Send the CR50 form and proof of deposit to webreg@chula.ac.th
# 5. The staff will verify your information and send the details to retrieve the new card to your e -mail,
# then you can proceed to the next step in the CUNEX Application....
# Metadata: {'source': '/content/CR99_2023_EngS.pdf', 'creator': 'Microsoft® Word 2013', 'total_pages': 35, 'author': 'Office of the Registrar', 'title': '', 'creationdate': '2023-09-22T15:10:46+07:00', 'producer': 'Microsoft® Word 2013', 'moddate': '2023-09-22T16:11:28+07:00', 'start_index': 1650, 'page': 9, 'page_label': '10'}
#
# ==================================================
# -- Document Relevance Rank no. 4 --
# Content: the bank to retrieve the new student card.
# a) Receipt Form for a Student Card
# b) Identification Card or Passport
# c) Kasikorn Bank Personal Records Modification Document (in case of name change)
# d) Original documents of the supplementary documents as submitted in No.2
# Credit Transfer for Students Studying in Other Institutes
# Procedures for s tudents who wished to study in other institutes within Thailand or overseas and
# have registered credits transferred back to Chualongkorn University are as follows. These
# procedures should be completed before the semester of the study in another institute.
# Studying Abroad
# 1. Proceed with Request for Study Abroad and Transferal of Credits at the Faculty
# 2. Before going abroad, you must contact the Office of the Registrar, Chamchuri 6 Building to
# pay tuition fee (study abroad). You will receive the payment slip, and then you can make the
# payment at the Office of the Registrar. The payment can only be done via bank transfer to...
# Metadata: {'producer': 'Microsoft® Word 2013', 'start_index': 749, 'author': 'Office of the Registrar', 'creator': 'Microsoft® Word 2013', 'page': 25, 'source': '/content/CR99_2023_EngS.pdf', 'total_pages': 35, 'moddate': '2023-09-22T16:11:28+07:00', 'creationdate': '2023-09-22T15:10:46+07:00', 'title': '', 'page_label': '26'}
#
# ==================================================

# %% [markdown]
# ## Retrieval and Generation
# - We now have the retrieval component (vector database). Next, we need to add the generation component (LLM) to complete the RAG pipeline.
#
# - The application will:
#   - Take a user question `[Input]`
#   - Search for documents relevant to that question `[Retrieval]`
#   - Pass the retrieved documents and the original question to a model `[Augmented]`
#   - Return the generated answer `[Generation]`
#
# - For generation, we will use the chat model selected at the beginning of this notebook.
# - We will define a simple RAG prompt directly with `ChatPromptTemplate` so this section is self-contained.

# %% [markdown]
# ### RAG Prompt Template
#
# The prompt tells the model to answer using the retrieved context. If the context does not contain enough information, the model should say that it does not know.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are an assistant for question-answering tasks. "
        "Use the retrieved context to answer the question. "
        "If you don't know the answer, say that you don't know. "
        "Keep the answer concise.\n\nContext:\n{context}"
    ),
    ("human", "{question}"),
])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Pull and see the prompt template we will use

# %%
example_messages = prompt.invoke({
    "context": "(context goes here)",
    "question": "(question goes here)"
}).to_messages()

for message in example_messages:
    print(f"{message.type.upper()}: {message.content}\n")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# SYSTEM: You are an assistant for question-answering tasks. Use the retrieved context to answer the question. If you don't know the answer, say that you don't know. Keep the answer concise.
#
# Context:
# (context goes here)
#
# HUMAN: (question goes here)

# %% [markdown]
# We'll use [LangGraph](https://langchain-ai.github.io/langgraph/) to tie together the retrieval and generation steps into a single application. This will bring a number of benefits:
#
# - We can define our application logic once and automatically support multiple invocation modes, including streaming, async, and batched calls.
# - We get streamlined deployments via [LangGraph Platform](https://langchain-ai.github.io/langgraph/concepts/langgraph_platform/).
# - LangSmith will automatically trace the steps of our application together.
# - We can easily add key features to our application, including [persistence](https://langchain-ai.github.io/langgraph/concepts/persistence/) and [human-in-the-loop approval](https://langchain-ai.github.io/langgraph/concepts/human_in_the_loop/), with minimal code changes.
#
# To use LangGraph, we need to define three things:
#
# 1. The state of our application;
# 2. The nodes of our application (i.e., application steps);
# 3. The "control flow" of our application (e.g., the ordering of the steps).

# %% [markdown]
# ### State
#
# The [state](https://langchain-ai.github.io/langgraph/concepts/low_level/#state) of our application controls what data is input to the application, transferred between steps, and output by the application. It is typically a `TypedDict`, but can also be a [Pydantic BaseModel](https://langchain-ai.github.io/langgraph/how-tos/state-model/).
#
# For a simple RAG application, we can just keep track of the input question, retrieved context, and generated answer:

# %%
from langchain_core.documents import Document
from typing_extensions import List, TypedDict

class State(TypedDict):
    question: str
    context: List[Document]
    answer: str
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Nodes (application steps)
#
# Let's start with a simple sequence of two steps: retrieval and generation.

# %%
def retrieve(state: State):
    retrieved_docs = vector_store.similarity_search(state["question"])
    return {"context": retrieved_docs}


def generate(state: State):
    docs_content = "\n\n".join(doc.page_content for doc in state["context"])
    messages = prompt.invoke({"question": state["question"], "context": docs_content})
    response = llm.invoke(messages)
    return {"answer": response.content}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Our retrieval step simply runs a similarity search using the input question, and the generation step formats the retrieved context and original question into a prompt for the chat model.

# %% [markdown]
# ### Control flow
#
# Finally, we compile our application into a single `graph` object. In this case, we are just connecting the retrieval and generation steps into a single sequence.

# %%
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# LangGraph also comes with built-in utilities for visualizing the control flow of your application:

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Usage

# %% [markdown]
# Let's test our application! LangGraph supports multiple invocation modes, including sync, async, and streaming.
#
# Invoke:

# %%
question = "What should I do if I lose my student card?"
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# **Output Stream:**

# %%
for step in graph.stream(
    {"question": question},
    stream_mode="updates"
):
    for node, output in step.items():

        print("=" * 70)
        print(f"NODE: {node}")
        print("=" * 70)

        print(output)
        print()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ======================================================================
# NODE: retrieve
# ======================================================================
# {'context': [Document(id='7c5e79fd-1c55-4c68-a956-44a107a7627d', metadata={'producer': 'Microsoft® Word 2013', 'start_index': 0, 'total_pages': 35, 'moddate': '2023-09-22T16:11:28+07:00', 'page_label': '10', 'creator': 'Microsoft® Word 2013', 'source': '/content/CR99_2023_EngS.pdf', 'title': '', 'page': 9, 'creationdate': '2023-09-22T15:10:46+07:00', 'author': 'Office of the Registrar'}, page_content='Student Card\nChulalongkorn University in cooperation with Kasikorn Bank (KBank) will issue student cards for\nevery new students in their first semester. Following are benefits and privileges of the student card:\n1. Identifying oneself as a student of the University to gain access to libraries and other facilities\nof the University such as CU Health Service Center and CU Sports Complex.\n2. Student card will also serve as a debit card of KBank. No application or annual fee is charged\nthroughout the period of study at Chulalongkorn University.\n3. Other privileges as announced by Kasikorn Bank.\nRequest for Replacement of Student Card\nRequest for replacement of student card due to defect, loss, expiration, or name change can\nbe done by 3 methods.\n\uf077 Request at the Office of the Registrar\n1. Submit CR50 form and pay 100 baht fee at the Office of the Registrar\n2. Bring the following documents to 2 branches of Kasikorn Bank (Chamchuri Square or'), Document(id='b0e7d481-72d1-446b-b0b4-1e870fe9314e', metadata={'moddate': '2023-09-22T16:11:28+07:00', 'page': 9, 'source': '/content/CR99_2023_EngS.pdf', 'title': '', 'page_label': '10', 'start_index': 752, 'total_pages': 35, 'creationdate': '2023-09-22T15:10:46+07:00', 'author': 'Office of the Registrar', 'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013'}, page_content='\uf077 Request at the Office of the Registrar\n1. Submit CR50 form and pay 100 baht fee at the Office of the Registrar\n2. Bring the following documents to 2 branches of Kasikorn Bank (Chamchuri Square or\nChulalongkorn Hospital) during business hours of the bank to retrieve the new student card.\na) Receipt Form for a Student Card\nb) Identification Card or Passport\nc) Kasikorn Bank Personal Records Modification Document (in case of name change)\nd) Kasikorn Bank Account Book Bank\n\uf077 Request Online\n1. Download CR50 form at www.reg.chula.ac.th\n2. Complete both section of the form.\n3. Deposit the amount of 100 baht to: SIAM COMMERCIAL BANK Account Name: Office of the\nRegistrar, Chulalongkorn University Account Number: 401-270276-5\n4. Send the CR50 form and proof of deposit to webreg@chula.ac.th\n5. The staff will verify your information and send the document to retrieve the new card to your e -mail\nwithin 3 working days.\n\uf077 Request via CUNEX Application (only in cases of loss, defect, or extension)'), Document(id='9175ad01-aa26-401c-b649-02ad3b3fcd70', metadata={'source': '/content/CR99_2023_EngS.pdf', 'start_index': 1650, 'title': '', 'author': 'Office of the Registrar', 'page': 9, 'producer': 'Microsoft® Word 2013', 'page_label': '10', 'moddate': '2023-09-22T16:11:28+07:00', 'total_pages': 35, 'creationdate': '2023-09-22T15:10:46+07:00', 'creator': 'Microsoft® Word 2013'}, page_content='within 3 working days.\n\uf077 Request via CUNEX Application (only in cases of loss, defect, or extension)\n1. Request for new student card through “Student Card” menu in CUNEX Application.\n2. Download CR50 form at www.reg.chula.ac.th and complete both section of the form.\n3. Deposit the amount of 100 baht to: SIAM COMMERCIAL BANK Account Name: Offi ce of the\nRegistrar, Chulalongkorn University Account Number: 401-270276-5\n4. Send the CR50 form and proof of deposit to webreg@chula.ac.th\n5. The staff will verify your information and send the details to retrieve the new card to your e -mail,\nthen you can proceed to the next step in the CUNEX Application.'), Document(id='442a633f-e03e-4e3f-a208-5bc44753d215', metadata={'total_pages': 35, 'producer': 'Microsoft® Word 2013', 'creationdate': ...
#
# ======================================================================
# NODE: generate
# ======================================================================
# {'answer': 'If you lose your student card, you can request a replacement using one of the following three methods:\n\n1.  **Request at the Office of the Registrar:**\n    *   Submit a CR50 form and pay a 100 baht fee at the Office of the Registrar.\n    *   Bring the required documents (Receipt Form, ID/Passport, and Bank Account Book) to one of the two Kasikorn Bank branches (Chamchuri Square or Chulalongkorn Hospital) to retrieve the new card.\n\n2.  **Request Online:**\n    *   Download and complete the CR50 form from www.reg.chula.ac.th.\n    *   Deposit 100 baht to the designated Siam Commercial Bank account (Office of the Registrar, Chulalongkorn University, Account Number: 401-270276-5).\n    *   Email the completed form and proof of deposit to webreg@chula.ac.th.\n    *   Staff will verify information and email you the document needed to retrieve the new card within 3 working days.\n\n3.  **Request via CUNEX Application:**\n    *   Request a new card through the “Student Card” menu in the CUNEX Application.\n    *   Download, complete, and email the CR50 form along with proof of the 100 baht deposit (to the same SCB account as above) to webreg@chula.ac.th.\n    *   Once staff verify your information and email the details, proceed with the next steps in the CUNEX Application.'}

# %% [markdown]
# # Agentic RAG
# In a normal RAG pipeline, the workflow is fixed and linear: retrieve relevant documents, then generate an answer.
#
# In this example, we make retrieval **conditional**. The LLM first decides whether the user's question requires the retrieval tool:
# - If retrieval is needed, the model calls the retrieval tool and the retrieved context is used to generate the answer.
# - If retrieval is not needed, the model can respond directly.
#
# This demonstrates a simple agentic RAG pattern where the LLM controls whether retrieval should happen.

# %% [markdown]
# ### State
#
# Instead of manually defining a message list and its reducer, LangGraph provides the prebuilt `MessagesState`.
#
# `MessagesState` contains a `messages` field with a message reducer that appends and merges conversation messages instead of overwriting them.
#
# In this example, the state may contain:
# 1. `HumanMessage` – the user's question.
# 2. `AIMessage` – the model response, which may contain a tool call.
# 3. `ToolMessage` – the result returned by the retrieval tool.
# 4. `AIMessage` – the final answer generated from the retrieved context.

# %%
from langgraph.graph import MessagesState, StateGraph

graph_builder = StateGraph(MessagesState) # Just one line instead of manual custom state function
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Node

# %% [markdown]
# Our graph will consist of three nodes:
#
# 1. A node that fields the user input, either generating a query for the retriever or responding directly;
# 2. A node for the retriever tool that executes the retrieval step;
# 3. A node that generates the final response using the retrieved context.
#
# We build them below. Note that we leverage another pre-built LangGraph component, [ToolNode](https://langchain-ai.github.io/langgraph/reference/prebuilt/#langgraph.prebuilt.tool_node.ToolNode), that executes the tool and adds the result as a `ToolMessage` to the state.

# %%
from langchain_core.messages import SystemMessage
from langgraph.prebuilt import ToolNode

# Step 1: Generate an AIMessage that may include a tool-call to be sent.
def query_or_respond(state: MessagesState):
    """Generate tool call for retrieval or respond."""
    llm_with_tools = llm.bind_tools([retrieve])
    response = llm_with_tools.invoke(state["messages"])
    # MessagesState appends messages to state instead of overwriting
    return {"messages": [response]}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Step 2A: Retrieval Tool
from langchain_core.tools import tool

@tool
def retrieve(query: str):
    """Retrieve information related to a query from a vector database containing information from the student's handbook."""
    retrieved_docs = vector_store.similarity_search(query, k=2)

    serialized = "\n\n".join(
        f"Source: {doc.metadata}\nContent: {doc.page_content}"
        for doc in retrieved_docs
    )

    return serialized
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Register the retrieval function as a ToolNode so that the agent recognizes it as a tool and can intelligently decide whether to perform a search (use the tool) or terminate, instead of following a strictly linear workflow.

# %%
# Step 2B Register a Tool (Retrieval) as ToolNode
tools = ToolNode([retrieve])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Step 3: Generation Node
def generate(state: MessagesState):
    """Generate answer."""
    # Collect recent ToolMessages from the conversation state.
    # (These messages store the outputs returned by any tools the agent used.)
    recent_tool_messages = []

    # Loop backward through the message list (from newest to oldest).
    # Stop once we hit the first non-tool message.
    for message in reversed(state["messages"]):
        if message.type == "tool": # "tool" marks messages generated by @tool functions
            recent_tool_messages.append(message)
        else:
            break
    tool_messages = recent_tool_messages[::-1]

    #  Format the retrieved tool outputs into a prompt for the LLM
    docs_content = "\n\n".join(doc.content for doc in tool_messages)

    # Build the system message that tells the model how to behave
    system_message_content = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer "
        "the question. If you don't know the answer, say that you "
        "don't know. Use three sentences maximum and keep the "
        "answer concise."
        "\n\n"
        f"{docs_content}"
    )

    # Keep only human, system, and normal AI messages.
    # (We exclude tool call messages since their outputs are already gathered in docs_content.)
    conversation_messages = [
        message
        for message in state["messages"]
        if message.type in ("human", "system")
        or (message.type == "ai" and not message.tool_calls)
    ]

    # Combine system message + conversation history into a full prompt
    prompt = [SystemMessage(system_message_content)] + conversation_messages

    # Run
    response = llm.invoke(prompt)
    return {"messages": [response]}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# - Finally, we compile our application into a single `graph` object.
# - In this case, we are just connecting the steps into a sequence. We also allow the first `query_or_respond` step to "short-circuit" and respond directly to the user if it does not generate a tool call.
# - This allows our application to support conversational experiences-- e.g., responding to generic greetings that may not require a retrieval step

# %% [markdown]
# ### Control Flow

# %%
from langgraph.graph import END
from langgraph.prebuilt import ToolNode, tools_condition

graph_builder.add_node(query_or_respond)
graph_builder.add_node(tools)
graph_builder.add_node(generate)

graph_builder.set_entry_point("query_or_respond")
graph_builder.add_conditional_edges(
    "query_or_respond",
    tools_condition,
    {END: END, "tools": "tools"},
)
graph_builder.add_edge("tools", "generate")
graph_builder.add_edge("generate", END)

graph = graph_builder.compile()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ### Persistent Chat History with Checkpointing
#
# To retain conversation history across multiple graph invocations, we can compile the graph with a **checkpointer**.
#
# Because `MessagesState` accumulates messages, the checkpointer can persist that state between turns. Invocations that use the same `thread_id` continue the same conversation, while a different `thread_id` starts a separate conversation.
#
# LangGraph provides an in-memory checkpointer for simple demonstrations. Production applications can use persistent backends such as SQLite or Postgres.

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver() # to support multi-turn conversation
graph = graph_builder.compile(checkpointer=memory)

# Specify an ID for the thread
config = {"configurable": {"thread_id": "test01"}}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# We can now invoke similar to before:

# %%
input_message = "What should I do if I lose my student card?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,  # same thread_id -> continue the same conversation
):
    step["messages"][-1].pretty_print()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ================================ Human Message =================================
#
# What should I do if I lose my student card?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve (apq36fd97)
#  Call ID: apq36fd97
#   Args:
#     query: lost student card
# ================================= Tool Message =================================
# Name: retrieve
#
# Source: {'creator': 'Microsoft® Word 2013', 'creationdate': '2023-09-22T15:10:46+07:00', 'moddate': '2023-09-22T16:11:28+07:00', 'author': 'Office of the Registrar', 'start_index': 752, 'page_label': '10', 'page': 9, 'source': '/content/CR99_2023_EngS.pdf', 'producer': 'Microsoft® Word 2013', 'title': '', 'total_pages': 35}
# Content:  Request at the Office of the Registrar
# 1. Submit CR50 form and pay 100 baht fee at the Office of the Registrar
# 2. Bring the following documents to 2 branches of Kasikorn Bank (Chamchuri Square or
# Chulalongkorn Hospital) during business hours of the bank to retrieve the new student card.
# a) Receipt Form for a Student Card
# b) Identification Card or Passport
# c) Kasikorn Bank Personal Records Modification Document (in case of name change)
# d) Kasikorn Bank Account Book Bank
#  Request Online
# 1. Download CR50 form at www.reg.chula.ac.th
# 2. Complete both section of the form.
# 3. Deposit the amount of 100 baht to: SIAM COMMERCIAL BANK Account Name: Office of the
# Registrar, Chulalongkorn University Account Number: 401-270276-5
# 4. Send the CR50 form and proof of deposit to webreg@chula.ac.th
# 5. The staff will verify your information and send the document to retrieve the new card to your e -mail
# within 3 working days.
#  Request via CUNEX Application (only in cases of loss, defect, or extension)
#
# Source: {'title': '', 'creator': 'Microsoft® Word 2013', 'page': 9, 'start_index': 0, 'producer': 'Microsoft® Word 2013', 'page_label': '10', 'author': 'Office of the Registrar', 'total_pages': 35, 'moddate': '2023-09-22T16:11:28+07:00', 'creationdate': '2023-09-22T15:10:46+07:00', 'source': '/content/CR99_2023_EngS.pdf'}
# Content: Student Card
# Chulalongkorn University in cooperation with Kasikorn Bank (KBank) will issue student cards for
# every new students in their first semester. Following are benefits and privileges of the student card:
# 1. Identifying oneself as a student of the University to gain access to libraries and other facilities
# of the University such as CU Health Service Center and CU Sports Complex.
# 2. Student card will also serve as a debit card of KBank. No application or annual fee is charged
# throughout the period of study at Chulalongkorn University.
# 3. Other privileges as announced by Kasikorn Bank.
# Request for Replacement of Student Card
# Request for replacement of student card due to defect, loss, expiration, or name change can
# be done by 3 methods.
#  Request at the Office of the Registrar
# 1. Submit CR50 form and pay 100 baht fee at the Office of the Registrar
# 2. Bring the following documents to 2 branches of Kasikorn Bank (Chamchuri Square or
# ================================== Ai Message ==================================
#
# To replace a lost student card, you must submit a CR50 form and pay a 100 baht fee at the Office of the Registrar. Alternatively, you can request the replacement online by downloading the CR50 form, depositing 100 baht into the specified Siam Commercial Bank account, and sending the form with proof of deposit to webreg@chula.ac.th. You may also use the CUNEX application for this request.

# %% [markdown]
# You can notice a small difference between the human’s query and the AI’s query (tool calling).
#   - Human: `What should I do if I lose my student card?`
#   - AI: `what to do if I lose my student card`
#
# (The results may vary across different runs.)

# %% [markdown]
# Test: Multi-turn Conversation

# %%
input_message = "Which Kasikorn Bank branches can I go to?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ================================ Human Message =================================
#
# Which Kasikorn Bank branches can I go to?
# ================================== Ai Message ==================================
#
# You can go to the following two Kasikorn Bank branches to retrieve your new student card:
#
# 1.  **Chamchuri Square**
# 2.  **Chulalongkorn Hospital**
#
# Please ensure you visit during the bank's business hours and bring the required documents (Receipt Form for a Student Card, Identification Card or Passport, and any other relevant documents like a Kasikorn Bank Personal Records Modification Document or Account Book if applicable).

# %% [markdown]
# - You can notice that the AI’s query is `Kasikorn Bank branches for student card replacement`.
# - Student card replacement is still recognized even though it’s not mentioned in the turn-2 query. (turn-2 query from human is `Which Kasikorn Bank branches can I go to?
# `.
